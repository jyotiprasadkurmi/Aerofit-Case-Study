# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotiprasadkurmi/Aerofit-Case-Study/blob/main/Aerofit_Case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries and Datasets

# %%
# !gdown 1E8euQ6hPowSov91sHp1vsMNfzcUzPoBl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E8euQ6hPowSov91sHp1vsMNfzcUzPoBl
# To: /content/aerofit_treadmill.csv
# 100% 7.28k/7.28k [00:00<00:00, 22.5MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('aerofit_treadmill.csv')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# #Shape of the Data_Frame

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# *  The DF has 180 rows and 9 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# ####No Null value in the dataframe

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# *   Average Age is 29 with min age as 18 years and max age as 50 years.
# *   Average 💰Income is 53719 USD Per Year.
# *   Average 🏃🏾miles ran is 103.19 and min miles runnned is 21 miles and max miles runned is 360 miles.

# %%
df.value_counts()
# Out:
# Product  Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  Miles
# KP281    18   Male    14         Single         3      4        29562   112      1
# KP481    30   Female  13         Single         4      3        46617   106      1
#          31   Female  16         Partnered      2      3        51165   64       1
#                       18         Single         2      1        65220   21       1
#               Male    16         Partnered      3      3        52302   95       1
#                                                                                 ..
# KP281    34   Female  16         Single         2      2        52302   66       1
#               Male    16         Single         4      5        51165   169      1
#          35   Female  16         Partnered      3      3        60261   94       1
#                       18         Single         3      3        67083   85       1
# ...

# %%
df_product = df.groupby('Product')['Product'].count()
df_product
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %% [markdown]
# *   In the dataset we have a sample of 80 KP281 models, 60 KP481 models and 40 KP781 models

# %%
###############👳🏻‍♂️👩🏻‍🦰 Distribution of gender 👳🏻‍♂️👩🏻‍🦰 ####################

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
plt.pie(df['Gender'].value_counts(), labels=['Male', 'Female'],explode = (0,0.1),startangle = 90, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# 👳🏻‍♂️ *Male Percentage who used the product is at 57.8%*
# 👩🏻‍🦰 *Female Percentage who used the product is at 42.2%*

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
# detecting the outliers

# %%
fig = plt.figure(figsize=(12,10))

sns.set_style("whitegrid")
plt.subplot(2,3,1)
sns.boxplot(data = df, y = 'Age', color = 'g')

sns.set_style("whitegrid")
plt.subplot(2,3,3)
sns.boxplot(data = df, y = 'Income', color = 'r')

sns.set_style("whitegrid")
plt.subplot(2,3,4)
sns.boxplot(data = df, y = 'Miles', color = 'r')

sns.set_style("whitegrid")
plt.subplot(2,3,6)
sns.boxplot(data = df, y = 'Fitness', color = 'g')

plt.show()

# %%
df['Age'].describe()
# Out:
# count    180.000000
# mean      28.788889
# std        6.943498
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       33.000000
# max       50.000000
# Name: Age, dtype: float64

# %%
#_____checking mean median and mode______
mean = df['Age'].mean()
median = df['Age'].median()
mode = df['Age'].mode()
print(mean,median,mode)
# Out:
# 28.788888888888888 26.0 0    25
# Name: Age, dtype: int64

# %%
# ________difference between mean and median___________
diff = mean - median
print(diff)
# Out:
# 2.788888888888888

# %%
#Check if features like marital status, age have any effect on the product purchased

# %%
df.groupby('MaritalStatus')['Product'].value_counts()
# Out:
# MaritalStatus  Product
# Partnered      KP281      48
#                KP481      36
#                KP781      23
# Single         KP281      32
#                KP481      24
#                KP781      17
# Name: count, dtype: int64

# %%
x1 = df.groupby('Product')['Product'].count()
x1
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#___________Product_count_____________
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.countplot(data = df, x = 'Product')
plt.title('Product Count')
plt.show()

# %% [markdown]
# *Most customers ordered KP281 model follwed by KP481 and KP781*

# %%
#Age and Product relation
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.histplot(data = df, x = 'Age', hue = 'Product')
plt.title('Age and Product relation')
plt.show()

# %% [markdown]
# * *Here we can see that KP281 model is the most sought product across different age groups*

# %%
#Age and Product relation
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.boxplot(x = 'Product', y = 'Age', data = df, color = 'r')
plt.title('Age and Product relation')
plt.show()

# %%
#Gender and Product relation
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.countplot(data = df, x = 'Product', hue = 'Gender')
plt.title('Gender and Product relation')
plt.show()

# %% [markdown]
# *   *Male and Female both bought the KP281 models Equally*
# *   *KP781 model was nostly bought by male customers*

# %%
#MaritalStatus
single = len(df[df['MaritalStatus'] == 'Single'])
married = len(df[df['MaritalStatus'] == 'Partnered'])

sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
plt.pie(x = [single,married], labels = ['Single', 'Married'],explode = (0,0.1),startangle = 90, autopct = '%1.1f%%')
plt.title('MaritalStatus')
plt.show()

# %% [markdown]
# *   *Total 40.6% Single people have bought the product*
# *   *Total 59.4% Married people have bought the product*

# %%
#Income and Product Relation
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.boxplot(data = df, x = 'Product', y = 'Income',color = 'r')
plt.title('Income and Product relation')
plt.show()

# %% [markdown]
# 1.   *We can see here that customers who have higher 💰income range tends to buy the top KP781 model.*
# 2.   *Here Aerofit can market the top KP781 model to the high 💰income range individuals*

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.countplot(data = df, x = 'MaritalStatus', hue = 'Product')
plt.title('Product across different groups')
plt.show()

# %% [markdown]
# *   *KP281 was mostly sought by Partnered Couple 👫*
# *   *KP281 was also the most sought product for the Single group 🧍🏻‍♂️*
#
# *🎊Overall KP281 is the people's favourite and why it won't be because the KP281 is an entry-level treadmill that sells for $1,500 Only🎊*

# %%
#_____________Income across different groups_______________
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.boxplot(data = df, x = 'MaritalStatus', y = 'Income', color = 'r')
plt.title('Income across different groups')
plt.show()

# %% [markdown]
# *   *Partnered Groups were the most high salaried individuals*

# %%
#Representing the marginal probability like - what percent of customers have purchased KP281, KP481, or KP781 in a table

# %%
probability = pd.crosstab(index = df['Product'],columns = 'count', normalize = True)
probability *= 100
probability.round(2)
# Out:
# col_0    count
# Product
# KP281    44.44
# KP481    33.33
# KP781    22.22

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
plt.pie(prob['count'], labels = ['KP281', 'KP481', 'KP781'],explode = (0.1,0.1,0.1),startangle = 90, autopct = '%.2f%%')
plt.show()

# %% [markdown]
# *   *KP281 model was the most used product i.e. by 44.4% of the population*

# %%
#________correlation____________

# %%
x = df[['Age', 'Education', 'Usage',
       'Fitness', 'Income', 'Miles']].corr()

# %%
#correlation
sns.set_style('whitegrid')
plt.figure(figsize=(10,8))
sns.heatmap(x,cmap = 'coolwarm',annot = True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# What is the probability of a male customer buying a KP781 treadmill?

# %%
M_KP781 = df[df['Product'] == 'KP781']
male_cust = len(M_KP781[M_KP781['Gender'] == 'Male'])
male_cust

#total_cust
total_cust = len(M_KP781)
total_cust
#probability of male customer
prob_male_kp781 = (male_cust/total_cust)*100
prob_male_kp781
# Out:
# 82.5

# %% [markdown]
# *Probability of Male customer buying KP781 model is 82.5%*

# %%
#What is the probability of a female customer buying a KP781 treadmill?

# %%
F_KP781 = df[df['Product'] == 'KP781']
female_cust = len(F_KP781[F_KP781['Gender'] == 'Female'])


#total_cust
total_cust = len(F_KP781)
total_cust
#probability of male customer
prob_female_kp781 = (female_cust/total_cust)*100
prob_female_kp781
# Out:
# 17.5

# %% [markdown]
# *Probability of female customer buying KP781 model is 17.5%*

# %%
#What is the probability of a male customer buying a KP481 treadmill?

# %%
M_KP481 = df[df['Product'] == 'KP481']
male_cust = len(M_KP481[M_KP481['Gender'] == 'Male'])
male_cust

#total_cust
total_cust = len(M_KP481)
total_cust
#probability of male customer
prob_male_kp481 = (male_cust/total_cust)*100
prob_male_kp481
# Out:
# 51.66666666666667

# %% [markdown]
# *Probability of male customer buying KP481 model is 51.67%*

# %%
##What is the probability of a male customer buying a KP481 treadmill?

# %%
F_KP481 = df[df['Product'] == 'KP481']
female_cust = len(F_KP481[F_KP481['Gender'] == 'Female'])
female_cust

#total_cust
total_cust = len(F_KP481)
total_cust
#probability of male customer
prob_female_kp481 = (female_cust/total_cust)*100
prob_female_kp481
# Out:
# 48.333333333333336

# %% [markdown]
# *Probability of female customer buying KP481 model is 48.33%*

# %%
##What is the probability of a male customer buying a KP281 treadmill?
M_KP281 = df[df['Product'] == 'KP281']
male_cust = len(M_KP281[M_KP281['Gender'] == 'Male'])
male_cust

#total_cust
total_cust = len(M_KP281)
total_cust
#probability of male customer
prob_male_kp281 = (male_cust/total_cust)*100
prob_male_kp281
# Out:
# 50.0

# %% [markdown]
# *Probability of male customer buying KP281 model is 50.0%*

# %%
##What is the probability of a female customer buying a KP281 treadmill?
F_KP281 = df[df['Product'] == 'KP281']
female_cust = len(F_KP281[F_KP281['Gender'] == 'Female'])
male_cust

#total_cust
total_cust = len(F_KP281)
total_cust
#probability of male customer
prob_female_kp281 = (female_cust/total_cust)*100
prob_female_kp281
# Out:
# 50.0

# %% [markdown]
# *Probability of female customer buying KP281 model is 50.0%*

# %% [markdown]
# #🧐INSIGHTS
#
#
# 1. Average Age of the customers is 29 with minimum age as 18 years and max age as 50 years.
# 2. Average 💰Income is at 53719 USD Per Year.
# 3. Average 🏃🏾miles ran is 103.19 and min miles runnned is 21 miles and max miles runned is 360 miles.
# 4. 👳🏻‍♂️ Male Percentage who used the product is at 57.8% 👩🏻‍🦰 Female Percentage who used the product is at 42.2%
# 5. Most customers ordered KP281 model follwed by KP481 and KP781
# 6. **KP281** model was the most used product among different age groups
# 7. **KP781** model which was expensive product among all  was mostly     bought     by the age group from 22 - 38.
# 8. KP281 was mostly sought by Partnered Couple 👫
# 9. KP281 was also the most sought product for the Single group 🧍🏻‍♂️
# 10. 🎊Overall KP281 is the people's favourite and why it won't be because the KP281 is an entry-level treadmill that sells for $1,500 Only🎊
# 11. Partnered Individuals were among the high salaried individuals.

# %% [markdown]
# # 📊RECOMMENDATIONS
#
#
# 1.   Since KP781 model was bought by high income individuals, Aerofit should mainly market this model to this range of customers.
# 2. KP281 model was mostly used by the customers and this model is affordable one, Aerofit could also come up with product for the price sensitive market, which sells more and generates more revenue.
# 3.   We have also seen that mostly Married people bought the products so, Aerofit could make specialized ad campaigns for the couple to attract more customers.
